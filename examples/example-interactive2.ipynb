# %%
import numpy
from biggles import plot_hist

x = numpy.random.lognormal(mean=0.01, sigma=0.3, size=10000)

plot_hist(x, nbin=50, xlabel='data', aspect_ratio=1.0/1.62)
# Out:
# <biggles.FramedPlot instance>
